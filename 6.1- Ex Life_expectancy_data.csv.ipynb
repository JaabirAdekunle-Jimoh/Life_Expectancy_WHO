# %% [markdown]
# # 01. Importing Libraries

# %%
# import libraries
import pandas as pd 
import numpy as np
import os

# %% [markdown]
# # 02. Defining Path

# %%
df=pd.read_csv(r'C:\Users\Jimadek\Answer 6.1-Jaabir\02 Data\Original Data\Life Expectancy Data.csv',index_col=False)

# %%
# Define the Path
path = r'C:\Users\Jimadek\Answer 6.1-Jaabir'

# %%
path
# Out:
# 'C:\\Users\\Jimadek\\Answer 6.1-Jaabir'

# %% [markdown]
# # 03. Importing Life Expectancy Data.csv

# %%
# import Life expectancy data.csv
df_life = pd.read_csv(os.path.join(path,'02 Data','Original Data','Life Expectancy Data.csv'))

# %%
# View Life expectancy data.csv
df_life.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df_life.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# Check for the mean and use it to replace the missing values
df_life.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df_life.median()
# Out:
# C:\Users\Jimadek\AppData\Local\Temp\ipykernel_7948\3392263260.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_life.median()
# Year                               2.008000e+03
# Life expectancy                    7.210000e+01
# Adult Mortality                    1.440000e+02
# infant deaths                      3.000000e+00
# Alcohol                            3.755000e+00
# percentage expenditure             6.491291e+01
# Hepatitis B                        9.200000e+01
# Measles                            1.700000e+01
#  BMI                               4.350000e+01
# under-five deaths                  4.000000e+00
# Polio                              9.300000e+01
# Total expenditure                  5.755000e+00
# ...

# %% [markdown]
# # 04. Cleaning Life Expectancy Data.csv

# %%
# Find missing values in df_life
df_life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Create a subset of dataframe with only the missing values in question
df_nan1 = df_life[df_life['Alcohol'].isnull()==True]

# %%
df_nan1
# Out:
#                                  Country  Year      Status  Life expectancy   \
# 32                               Algeria  2015  Developing              75.6
# 48                                Angola  2015  Developing              52.4
# 64                   Antigua and Barbuda  2015  Developing              76.4
# 80                             Argentina  2015  Developing              76.3
# 96                               Armenia  2015  Developing              74.8
# ...                                  ...   ...         ...               ...
# 2858  Venezuela (Bolivarian Republic of)  2015  Developing              74.1
# 2874                            Viet Nam  2015  Developing              76.0
# 2890                               Yemen  2015  Developing              65.7
# 2906                              Zambia  2015  Developing              61.8
# 2922                            Zimbabwe  2015  Developing              67.0
#
# ...

# %%
# Fill NaN with column median in 'Alcohol' column
df_life['Alcohol']= df_life['Alcohol'].fillna(df_life['Alcohol'].median())

# %%
df_life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# View the missing values in 'Adult Mortality'
df_nan2 = df_life[df_life['Adult Mortality'].isnull()==True]

# %%
df_nan2
# Out:
#                     Country  Year      Status  Life expectancy   \
# 624            Cook Islands  2013  Developing               NaN
# 769                Dominica  2013  Developing               NaN
# 1650       Marshall Islands  2013  Developing               NaN
# 1715                 Monaco  2013  Developing               NaN
# 1812                  Nauru  2013  Developing               NaN
# 1909                   Niue  2013  Developing               NaN
# 1958                  Palau  2013  Developing               NaN
# 2167  Saint Kitts and Nevis  2013  Developing               NaN
# 2216             San Marino  2013  Developing               NaN
# 2713                 Tuvalu  2013  Developing               NaN
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 624               NaN              0    0.010                0.000000
# 769               NaN              0    0.010               11.419555
# ...

# %%
# Fill NaN with column median in 'Adult Mortality' column
df_life['Adult Mortality']= df_life['Adult Mortality'].fillna(df_life['Adult Mortality'].median())

# %%
df_life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Rename 'Life Expectancy' to remove extra space
df_life.rename(columns = {'Life expectancy ':'Life expectancy'}, inplace = True)

# %%
# View the missing values in 'Life expectancy '
df_nan3 = df_life[df_life['Life expectancy'].isnull()==True]

# %%
df_nan3
# Out:
#                     Country  Year      Status  Life expectancy  \
# 624            Cook Islands  2013  Developing              NaN
# 769                Dominica  2013  Developing              NaN
# 1650       Marshall Islands  2013  Developing              NaN
# 1715                 Monaco  2013  Developing              NaN
# 1812                  Nauru  2013  Developing              NaN
# 1909                   Niue  2013  Developing              NaN
# 1958                  Palau  2013  Developing              NaN
# 2167  Saint Kitts and Nevis  2013  Developing              NaN
# 2216             San Marino  2013  Developing              NaN
# 2713                 Tuvalu  2013  Developing              NaN
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 624             144.0              0    0.010                0.000000
# 769             144.0              0    0.010               11.419555
# ...

# %%
# Fill NaN with column median in 'Life expectancy' column
df_life['Life expectancy']= df_life['Life expectancy'].fillna(df_life['Life expectancy'].median())

# %%
df_life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# View the missing values in 'Hepatitis B '
df_nan4 = df_life[df_life['Hepatitis B'].isnull()==True]

# %%
df_nan4
# Out:
#       Country  Year      Status  Life expectancy  Adult Mortality  \
# 44    Algeria  2003  Developing             71.7            146.0
# 45    Algeria  2002  Developing             71.6            145.0
# 46    Algeria  2001  Developing             71.4            145.0
# 47    Algeria  2000  Developing             71.3            145.0
# 57     Angola  2006  Developing             47.7            381.0
# ...       ...   ...         ...              ...              ...
# 2917   Zambia  2004  Developing             47.9            578.0
# 2918   Zambia  2003  Developing             46.4             64.0
# 2919   Zambia  2002  Developing             45.5             69.0
# 2920   Zambia  2001  Developing             44.6            611.0
# 2921   Zambia  2000  Developing             43.8            614.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 44               20     0.34               25.018523          NaN     15374
# ...

# %%
# Fill NaN with column mean in 'Hepatitis B' column
df_life['Hepatitis B']= df_life['Hepatitis B'].fillna(df_life['Hepatitis B'].mean())

# %%
df_life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                          0
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Rename ' BMI 'to to remove extra spaces
df_life.rename(columns = {' BMI ':'BMI'}, inplace = True)

# %%
# Fill NaN with column mean in 'BMI' column
df_life['BMI']= df_life['BMI'].fillna(df_life['BMI'].mean())

# %%
# Fill NaN with column mean in 'Polio ' column
df_life['Polio']= df_life['Polio'].fillna(df_life['Polio'].mean())

# %%
# Fill NaN with column mean in 'Total expenditure' column
df_life['Total expenditure']= df_life['Total expenditure'].fillna(df_life['Total expenditure'].mean())

# %%
# Rename 'Diphtheria ' to to remove extra spaces
df_life.rename(columns = {'Diphtheria ':'Diphtheria'}, inplace = True)

# %%
# Fill NaN with column mean in 'Total expenditure' column
df_life['Diphtheria']= df_life['Diphtheria'].fillna(df_life['Diphtheria'].mean())

# %%
df_life.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                          0
# Measles                              0
# BMI                                  0
# under-five deaths                    0
# Polio                                0
# Total expenditure                    0
# Diphtheria                           0
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# View the missing values in 'GDP'
df_nan5 = df_life[df_life['GDP'].isnull()==True]

# %%
df_nan5
# Out:
#       Country  Year      Status  Life expectancy  Adult Mortality  \
# 160   Bahamas  2015  Developing             76.1            147.0
# 161   Bahamas  2014  Developing             75.4             16.0
# 162   Bahamas  2013  Developing             74.8            172.0
# 163   Bahamas  2012  Developing             74.9            167.0
# 164   Bahamas  2011  Developing             75.0            162.0
# ...       ...   ...         ...              ...              ...
# 2901    Yemen  2004  Developing             62.2            247.0
# 2902    Yemen  2003  Developing             61.9            249.0
# 2903    Yemen  2002  Developing             61.5             25.0
# 2904    Yemen  2001  Developing             61.1            251.0
# 2905    Yemen  2000  Developing             68.0            252.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 160               0    3.755                     0.0         95.0         0
# ...

# %% [markdown]
# # 05. Merge df_life with df_cc

# %%
# import Country & Contient.csv
df_cc = pd.read_csv(os.path.join(path,'02 Data','Original Data','Country & Contient.csv'))

# %%
# View imported dataset
df_cc.head()
# Out:
#                Country      Continent
# 0          Afghanistan           Asia
# 1              Albania         Europe
# 2              Algeria         Africa
# 3               Angola         Africa
# 4  Antigua and Barbuda  North America

# %%
#Merge df_life with df_cc
df_merged = df_life.merge(df_cc, on = ['Country'], how = 'left')

# %%
df_merged.tail(20)
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
# 2923  Zimbabwe  2014  Developing             59.2            371.0
# 2924  Zimbabwe  2013  Developing             58.0            399.0
# 2925  Zimbabwe  2012  Developing             56.6            429.0
# 2926  Zimbabwe  2011  Developing             54.9            464.0
# 2927  Zimbabwe  2010  Developing             52.4            527.0
# 2928  Zimbabwe  2009  Developing             50.0            587.0
# 2929  Zimbabwe  2008  Developing             48.2            632.0
# 2930  Zimbabwe  2007  Developing             46.6             67.0
# ...

# %%
# View the missing values in 'Continent'
df_nan6 = df_merged[df_merged['Continent'].isnull()==True]

# %%
df_nan6.head(16)
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles , BMI, under-five deaths , Polio, Total expenditure, Diphtheria,  HIV/AIDS, GDP, Population,  thinness  1-19 years,  thinness 5-9 years, Income composition of resources, Schooling, Continent]
# Index: []
#
# [0 rows x 23 columns]
